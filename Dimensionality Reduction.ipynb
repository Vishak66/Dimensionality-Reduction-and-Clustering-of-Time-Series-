# %%
#importing libraries

import numpy as np
import h5py
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import os
os.getcwd()
# Out:
# 'E:\\SRA_Groeber\\Data'

# %%
#Reading the file

filename = 'file.hdf5'
f = h5py.File("ThermalHistories.hdf5", 'r')

# %%
# List all groups
list(f.keys())
# Out:
# ['ThermalHistories']

# %%
# Get the data
data = f['ThermalHistories']

# %%
data
# Out:
# <HDF5 group "/ThermalHistories" (13800 members)>

# %%
len(data)
# Out:
# 13800

# %%
for key in data.keys():
    print(key)
# Out:
# 0
# 1
# 10
# 100
# 1000
# 10000
# 10001
# 10002
# 10003
# 10004
# 10005
# 10006
# 10007
# 10008
# 10009
# 1001
# 10010
# 10011
# 10012
# 10013
# 10014
# 10015
# 10016
# 10017
# 10018
# 10019
# 1002
# 10020
# 10021
# 10022
# 10023
# 10024
# 10025
# 10026
# 10027
# 10028
# 10029
# 1003
# 10030
# 10031
# 10032
# 10033
# 10034
# 10035
# 10036
# 10037
# 10038
# 10039
# 1004
# 10040
# 10041
# 10042
# 10043
# 10044
# 10045
# 10046
# 10047
# 10048
# 10049
# 1005
# 10050
# 10051
# 10052
# 10053
# 10054
# 10055
# 10056
# 10057
# 10058
# 10059
# 1006
# 10060
# 10061
# 10062
# 10063
# 10064
# 10065
# 10066
# 10067
# 10068
# 10069
# 1007
# 10070
# 10071
# 10072
# 10073
# 10074
# 10075
# 10076
# 10077
# 10078
# 10079
# 1008
# 10080
# 10081
# 10082
# 10083
# 10084
# 10085
# 10086
# 10087
# 10088
# 10089
# 1009
# 10090
# 10091
# 10092
# 10093
# 10094
# 10095
# 10096
# 10097
# 10098
# 10099
# 101
# 1010
# 10100
# 10101
# 10102
# 10103
# 10104
# 10105
# 10106
# 10107
# 10108
# 10109
# 1011
# 10110
# ...

# %%
X=[None]*13800

# %%
for key in data.keys():
    X[int(key)]=data[key]

# %%
X
# Out:
# [<HDF5 dataset "0": shape (1,), type "<f4">,
#  <HDF5 dataset "1": shape (1,), type "<f4">,
#  <HDF5 dataset "2": shape (1,), type "<f4">,
#  <HDF5 dataset "3": shape (1,), type "<f4">,
#  <HDF5 dataset "4": shape (1,), type "<f4">,
#  <HDF5 dataset "5": shape (1,), type "<f4">,
#  <HDF5 dataset "6": shape (1,), type "<f4">,
#  <HDF5 dataset "7": shape (1,), type "<f4">,
#  <HDF5 dataset "8": shape (1,), type "<f4">,
#  <HDF5 dataset "9": shape (1,), type "<f4">,
#  <HDF5 dataset "10": shape (1,), type "<f4">,
#  <HDF5 dataset "11": shape (1,), type "<f4">,
#  <HDF5 dataset "12": shape (1,), type "<f4">,
#  <HDF5 dataset "13": shape (1,), type "<f4">,
#  <HDF5 dataset "14": shape (1,), type "<f4">,
#  <HDF5 dataset "15": shape (1,), type "<f4">,
#  <HDF5 dataset "16": shape (1,), type "<f4">,
#  <HDF5 dataset "17": shape (1,), type "<f4">,
#  <HDF5 dataset "18": shape (1,), type "<f4">,
#  <HDF5 dataset "19": shape (1,), type "<f4">,
#  <HDF5 dataset "20": shape (1,), type "<f4">,
# ...

# %%
type(X)
# Out:
# list

# %%
max_len = max([len(i) for i in X])
print(max_len)
# Out:
# 8380

# %%
# Seeing all images which have all entries 

for i in X:
    if(len(i)==8380):
        print(i)
# Out:
# <HDF5 dataset "2614": shape (8380,), type "<f4">
# <HDF5 dataset "2732": shape (8380,), type "<f4">
# <HDF5 dataset "2734": shape (8380,), type "<f4">
# <HDF5 dataset "7644": shape (8380,), type "<f4">
# <HDF5 dataset "7764": shape (8380,), type "<f4">
# <HDF5 dataset "8127": shape (8380,), type "<f4">
# <HDF5 dataset "8247": shape (8380,), type "<f4">

# %%
# Filling the array with unequal entries with zeros

X_array = np.zeros([len(X),len(max(X,key = lambda x: len(x)))])
for i,j in enumerate(X):
    X_array[i][0:len(j)] = j

# %%
X_array.shape
# Out:
# (13800, 8380)

# %%
X_array[2614]
# Out:
# array([100., 100., 100., ..., 100., 100., 100.])

# %% [markdown]
# ## PCA

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_array
# Out:
# (13800, 8380)

# %%
X_array_df = pd.DataFrame(data=X_array)

# %%
X_array_df.describe()
# Out:
#           0             1             2             3             4     \
# count  13800.0  13800.000000  13800.000000  13800.000000  13800.000000
# mean     100.0     64.801589     65.140506     65.226311     65.629111
# std        0.0     72.620135     79.266033     66.570879     73.147701
# min      100.0      0.000000      0.000000      0.000000      0.000000
# 25%      100.0      0.000000      0.000000      0.000000      0.000000
# 50%      100.0    100.000000    100.000000    100.000000    100.000000
# 75%      100.0    100.000000    100.000000    100.000000    100.000000
# max      100.0   6472.043945   6717.947754   4319.792969   4033.881592
#
#                5             6             7             8             9     \
# count  13800.000000  13800.000000  13800.000000  13800.000000  13800.000000
# mean      66.250741     66.825871     67.194507     67.368661     67.357926
# std       91.504478    101.332950    106.058914    103.330263     87.581649
# ...

# %%
pca = PCA()
pca.fit(X_array)
cumsum = np.cumsum(pca.explained_variance_ratio_)

# %%
cumsum
# Out:
# array([0.43492066, 0.652458  , 0.72327512, ..., 1.        , 1.        ,
#        1.        ])

# %%
cumsum[20]
# Out:
# 0.9003643941293057

# %%
plt.figure(figsize=(10,10))
plt.plot(cumsum)
plt.xlim(0,30,1)
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0,0.5,'Cumulative explained variance')

# %% [markdown]
# ### PCA (N=3)

# %%
cumsum[3]
# Out:
# 0.7519349440844791

# %%
pca = PCA(n_components=3)
X_array_new = pca.fit_transform(X_array)

# %%
X_array_new.shape
# Out:
# (13800, 3)

# %%
X_rec = pca.inverse_transform(X_array_new)

# %%
X_rec.shape
# Out:
# (13800, 8380)

# %%
plt.figure(figsize=(10,8))
plt.plot(X_array[2614])
plt.title("Original image without standardising")
# Out:
# Text(0.5,1,'Original image without standardising')

# %%
plt.figure(figsize=(10,8))
plt.plot(X_rec[2614])
plt.title("Reconstructed image after PCA")
# Out:
# Text(0.5,1,'Reconstructed image after PCA')

# %% [markdown]
# ### PCA (N=5)

# %%
cumsum[5]
# Out:
# 0.7956960790033338

# %%
pca = PCA(n_components=5)
X_array_new = pca.fit_transform(X_array)

# %%
X_array_new.shape
# Out:
# (13800, 5)

# %%
X_rec = pca.inverse_transform(X_array_new)

# %%
X_rec.shape
# Out:
# (13800, 8380)

# %%
plt.figure(figsize=(10,8))
plt.plot(X_array[2614])
plt.title("Original image without standardising")
# Out:
# Text(0.5,1,'Original image without standardising')

# %%
plt.figure(figsize=(10,8))
plt.plot(X_rec[2614])
plt.title("Reconstructed image after PCA")
# Out:
# Text(0.5,1,'Reconstructed image after PCA')

# %% [markdown]
# ### PCA (N=10)

# %%
cumsum[10]
# Out:
# 0.8541230764890438

# %%
pca = PCA(n_components=10)
X_array_new = pca.fit_transform(X_array)

# %%
X_array_new.shape
# Out:
# (13800, 10)

# %%
X_rec = pca.inverse_transform(X_array_new)

# %%
X_rec.shape
# Out:
# (13800, 8380)

# %%
plt.figure(figsize=(10,8))
plt.plot(X_array[2614])
plt.title("Original image after standardising")
# Out:
# Text(0.5,1,'Original image after standardising')

# %%
plt.figure(figsize=(10,8))
plt.plot(X_rec[2614])
plt.title("Reconstructed image after PCA")
# Out:
# Text(0.5,1,'Reconstructed image after PCA')

# %% [markdown]
# ### PCA (N=20)

# %%
cumsum[20]
# Out:
# 0.9003643941293057

# %%
pca = PCA(n_components=20)
X_array_new = pca.fit_transform(X_array)

# %%
X_array_new.shape
# Out:
# (13800, 20)

# %%
X_rec = pca.inverse_transform(X_array_new)

# %%
X_rec.shape
# Out:
# (13800, 8380)

# %%
plt.figure(figsize=(10,8))
plt.plot(X_array[2614])
plt.title("Original image after standardising")
# Out:
# Text(0.5,1,'Original image after standardising')

# %%
plt.figure(figsize=(10,8))
plt.plot(X_rec[2614])
plt.title("Reconstructed image after PCA")
# Out:
# Text(0.5,1,'Reconstructed image after PCA')

# %% [markdown]
# ## K Means

# %% [markdown]
# ### Number of components =3 from PCA

# %%
from sklearn.cluster import KMeans

# %%
X_array_new.shape
# Out:
# (13800, 3)

# %% [markdown]
# ### Elbow method

# %%
cluster_range = range( 1, 20 )
cluster_errors = []

for num_clusters in cluster_range:
    clusters = KMeans( num_clusters )
    clusters.fit( X_array_new )
    cluster_errors.append( clusters.inertia_ )
    
clusters_df = pd.DataFrame( { "num_clusters":cluster_range, "cluster_errors": cluster_errors } )
plt.figure(figsize=(12,6))
plt.plot( clusters_df.num_clusters, clusters_df.cluster_errors, marker = "o" )

# %% [markdown]
# ### Choosing number of clusters as 3

# %%
# Number of clusters
kmeans = KMeans(n_clusters=3)
# Fitting the input data
kmeans = kmeans.fit(X_array_new)
# Getting the cluster labels
labels = kmeans.predict(X_array_new)
# Centroid values
centroids = kmeans.cluster_centers_

#Unique labels
np.unique(labels)
# Out:
# array([0, 1, 2])

# %%
zero=0
one=0
two=0
for i in labels:
    if i==0:
        zero=zero+1
    elif i==1:
        one=one+1
    elif i==2:
        two=two+1

# %%
print("Number of entries with 0 as the label :" , zero)
print("Number of entries with 1 as the label :" , one)
print("Number of entries with 2 as the label :" , two)
# Out:
# Number of entries with 0 as the label : 8860
# Number of entries with 1 as the label : 2812
# Number of entries with 2 as the label : 2128

# %%
X_array_new_df=pd.DataFrame(X_array_new)
X_array_new_df['Labels']=labels
X_array_new_df.columns = ["PC1","PC2","PC3","Labels"]

# %%
X_array_new_df
# Out:
#                PC1          PC2          PC3  Labels
# 0     -5513.523213  -885.520925 -1080.255413       1
# 1     -5513.523213  -885.520925 -1080.255413       1
# 2     -5513.523213  -885.520925 -1080.255413       1
# 3     -5513.523213  -885.520925 -1080.255413       1
# 4     -5513.523213  -885.520925 -1080.255413       1
# 5     -5513.523213  -885.520925 -1080.255413       1
# 6     -5513.523213  -885.520925 -1080.255413       1
# 7     -5513.523213  -885.520925 -1080.255413       1
# 8     -5513.523213  -885.520925 -1080.255413       1
# 9     -5513.523213  -885.520925 -1080.255413       1
# 10    -5513.523213  -885.520925 -1080.255413       1
# 11    -5513.523213  -885.520925 -1080.255413       1
# 12    -5513.523213  -885.520925 -1080.255413       1
# 13    -5513.523213  -885.520925 -1080.255413       1
# 14    -5513.523213  -885.520925 -1080.255413       1
# 15    -5513.523213  -885.520925 -1080.255413       1
# 16    -5513.523213  -885.520925 -1080.255413       1
# ...

# %% [markdown]
# ### Three dimensional plot for visualisation

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
plt.figure(figsize=(100,100))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X = X_array_new_df["PC1"]
Y = X_array_new_df["PC2"]
Z = X_array_new_df["PC3"]

ax.scatter(X,Y,Z, c=X_array_new_df["Labels"], marker ='o')
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
# Out:
# Text(0.5,0,'PC3')

# %% [markdown]
# ### Choosing number of clusters as 5

# %%
# Number of clusters
kmeans = KMeans(n_clusters=5)
# Fitting the input data
kmeans = kmeans.fit(X_array_new)
# Getting the cluster labels
labels = kmeans.predict(X_array_new)
# Centroid values
centroids = kmeans.cluster_centers_

#Unique labels
np.unique(labels)
# Out:
# array([0, 1, 2, 3, 4])

# %%
zero=0
one=0
two=0
three=0
four=0
for i in labels:
    if i==0:
        zero=zero+1
    elif i==1:
        one=one+1
    elif i==2:
        two=two+1
    elif i==3:
        three=three+1
    elif i==4:
        four=four+1

# %%
print("Number of entries with 0 as the label :" , zero)
print("Number of entries with 1 as the label :" , one)
print("Number of entries with 2 as the label :" , two)
print("Number of entries with 3 as the label :" , three)
print("Number of entries with 4 as the label :" , four)
# Out:
# Number of entries with 0 as the label : 1905
# Number of entries with 1 as the label : 4923
# Number of entries with 2 as the label : 2265
# Number of entries with 3 as the label : 3949
# Number of entries with 4 as the label : 758

# %%
X_array_new_df=pd.DataFrame(X_array_new)
X_array_new_df['Labels']=labels
X_array_new_df.columns = ["PC1","PC2","PC3","Labels"]

# %%
plt.figure(figsize=(100,100))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X = X_array_new_df["PC1"]
Y = X_array_new_df["PC2"]
Z = X_array_new_df["PC3"]

ax.scatter(X,Y,Z, c=X_array_sd_new_df["Labels"], marker ='o')

ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
# Out:
# Text(0.5,0,'PC3')
